# %%
Python Practice Assignment 1
Write a Python program that accepts the radius of a circle from the user and computes the area.
In [ ]:
#accept radius from the user:
rad= float(input("Enter the radius:"))\

#formula for area of a circle is pi*r^2 
area= 3.14*(rad**2)

#print the output
print("The area of the circle is:", area)
Write a Python program that accepts the user's first and last name and prints them in reverse order with a space between them.
In [ ]:
#accept first name and last name from the user:
f_name = input("Enter your first name:")
l_name = input("Enter your last name:")

#print in reverse order with a space:
print(l_name, f_name)

#alternatively:
#print(l_name, f_name, sep= " ")
Write a program that takes in a number from the user, and correctly prints either “That number is between 1 to 100” or “That number is not between 1 to 100”.
In [ ]:
#accept an integer from user:
num= int(input("Enter a number:"))

#Compare whether the number is between 1 to 100 or not : 
a = 1<= num <= 100

#print whether the integer is between 1 to 100 or not: 
if(a==True):
    print("That number is between 1 to 100")
else: 
    print("That number is not between 1 to 100")
Write a program that asks the user which province they live in. If the province isn’t “Saskatchewan” or “saskatchewan”, print out “You should come and visit Saskatchewan sometime!”.
In [ ]:
#accept the province name from the user:
pr = input("Enter the name of a province:")

#Compare and print whether the province name is Saskatchewan or not:
if(pr == "Saskatchewan" or pr == "saskatchewan"):
    print ("Welcome to Saskatchewan!")
else:
    print("You should come and visit Saskatchewan sometime!")
Write a program that asks the user to enter a number. You should print out a message to the user, either “That number is divisible by either 3 or 5”, or “That number is not divisible by either 3 or 5”. Be sure to consider the data type of the input you are taking in from the user.
In [ ]:
#accept a number from the user:
num = int(input("Enter a number:"))

#check whether it is divisible by 3 or 5 or not:
div3= num%3
div5 = num%5

if(div3==0 or div5==0):
    print("That number is divisible by either 3 or 5")
else:
    print("That number is not divisible by either 3 or 5")
Display “My Name Is James” as “My Name Is ** James” using output formatting of a print() function.
In [ ]:
#print the statement using appropriate separator:
print("My","Name","Is","James", sep= " ** ")
Accept any three strings from one input() function.
In [ ]:
# accept 3 strins using eval function:
str1, str2, str3 = eval(input("Enter multiple string values:"))

#print the values:
print("The inputed sting values were", str1, str2, str3)
Given two integer numbers return their product. If the product is greater than 1000, then return their sum.
In [ ]:
#accept 2 integer from user:
num1= int(input("Enter 1st integer: "))
num2= int(input("Enter 2nd integer: "))

#calculate the product and the sum:
mul= num1*num2
add= num1+num2

#print the result accordingly:
if(mul<=1000):
    print("The product is:", mul)
else:
    print("The sum is:", add)
